# %% [markdown]
# # Tuning Pipeline

# %%
from sklearn import set_config; set_config(display='diagram')
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# 👇 Consider the following dataset.

# %%
import pandas as pd

data = pd.read_csv("data.csv")

data.head()
# Out:
#    games played  minutes played  points per game  field goals made  \
# 0          36.0            27.4              7.4               2.6
# 1          35.0            26.9              NaN               2.0
# 2           NaN            15.3              5.2               2.0
# 3          58.0            11.6              5.7               2.3
# 4          48.0            11.5              4.5               1.6
#
#    field goal attempts  field goal percent  3 point made  3 point attempt  \
# 0                  7.6                 NaN           0.5              2.1
# 1                  6.7                29.6           0.7              2.8
# 2                  4.7                42.2           0.4              1.7
# 3                  5.5                42.6           0.1              0.5
# 4                  3.0                52.4           0.0              0.1
#
#    3 point %  free throw made  free throw attempts  free throw %  \
# 0       25.0              1.6                  2.3          69.9
# 1       23.5              2.6                  3.4          76.5
# 2       24.4              0.9                  1.3          67.0
# 3       22.6              0.9                  1.3          68.9
# 4        0.0              1.3                  1.9          67.4
#
#    offensive rebounds  defensive rebounds  rebounds  assists  steals  blocks  \
# 0                 0.7                 3.4       4.1      1.9     0.4     0.4
# 1                 0.5                 2.0       2.4      3.7     1.1     0.5
# 2                 0.5                 1.7       2.2      1.0     0.5     0.3
# 3                 1.0                 0.9       1.9      0.8     0.6     0.1
# 4                 1.0                 1.5       2.5      0.3     0.3     0.4
#
#    turnovers  target_5y
# 0        1.3          0
# 1        1.6          0
# 2        1.0          0
# 3        1.0          1
# 4        0.8          1

# %% [markdown]
# - Each observations represents a player
# - Each column a characteristic of performance
#
# The target defines whether the player last less than 5 years `0` or 5 years or more `1` as a professional.

# %%
X = data.drop(columns="target_5y")
y = data['target_5y']

# %% [markdown]
# ## Pipeline

# %% [markdown]
# 👇 We are giving you the simple pipeline below

# %%
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer

# Preprocessing pipe
preprocessor = Pipeline([
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaling', MinMaxScaler())
])

# Final pipe
pipe = Pipeline([
    ('preprocessing', preprocessor),
    ('model_svm', SVC())])

pipe
# Out:
# Pipeline(steps=[('preprocessing',
#                  Pipeline(steps=[('imputer', SimpleImputer()),
#                                  ('scaling', MinMaxScaler())])),
#                 ('model_svm', SVC())])

# %% [markdown]
# ## Fine Tuning

# %% [markdown]
# Our task is to assist the recruitment process of promising young players.
# The model should **limit false alarms as much as possible** to avoid recruiting players that will flop.

# %% [markdown]
# ❓ **Fine-tune this pipeline so as to maximize your objective**
#
# - Use the `scoring` metric appropriate for the task
# - Grid Search for the optimal:
#     - imputing `strategy`
#     - `kernel`
#     - regularization factor `C`...
#
#
# - Store your random search results in a `search`

# %%
from sklearn import set_config; set_config(display='text')
pipe.get_params()
# Out:
# {'memory': None,
#  'steps': [('preprocessing',
#    Pipeline(steps=[('imputer', SimpleImputer()), ('scaling', MinMaxScaler())])),
#   ('model_svm', SVC())],
#  'verbose': False,
#  'preprocessing': Pipeline(steps=[('imputer', SimpleImputer()), ('scaling', MinMaxScaler())]),
#  'model_svm': SVC(),
#  'preprocessing__memory': None,
#  'preprocessing__steps': [('imputer', SimpleImputer()),
#   ('scaling', MinMaxScaler())],
#  'preprocessing__verbose': False,
#  'preprocessing__imputer': SimpleImputer(),
#  'preprocessing__scaling': MinMaxScaler(),
#  'preprocessing__imputer__add_indicator': False,
#  'preprocessing__imputer__copy': True,
#  'preprocessing__imputer__fill_value': None,
#  'preprocessing__imputer__missing_values': nan,
#  'preprocessing__imputer__strategy': 'mean',
#  'preprocessing__imputer__verbose': 0,
#  'preprocessing__scaling__clip': False,
#  'preprocessing__scaling__copy': True,
#  'preprocessing__scaling__feature_range': (0, 1),
#  'model_svm__C': 1.0,
#  'model_svm__break_ties': False,
#  'model_svm__cache_size': 200,
#  'model_svm__class_weight': None,
#  'model_svm__coef0': 0.0,
#  'model_svm__decision_function_shape': 'ovr',
#  'model_svm__degree': 3,
#  'model_svm__gamma': 'scale',
#  'model_svm__kernel': 'rbf',
#  'model_svm__max_iter': -1,
#  'model_svm__probability': False,
#  'model_svm__random_state': None,
#  'model_svm__shrinking': True,
#  'model_svm__tol': 0.001,
#  'model_svm__verbose': False}

# %%
grid_kernel = ['linear', 'poly', 'rbf', 'sigmoid']
grid_C = [1, 10, 100, 500, 1000]
grid_strategy = ['mean', 'median']


search = GridSearchCV(
    pipe, 
    param_grid={
        'preprocessing__imputer__strategy': grid_strategy,
        'model_svm__kernel': grid_kernel,
        'model_svm__C': grid_C
    },
    cv=5,
    scoring='precision', 
    refit="precision",
    n_jobs = -1
)

# %%
search.fit(X,y)
search.__dict__
# Out:
# {'scoring': 'precision',
#  'estimator': Pipeline(steps=[('preprocessing',
#                   Pipeline(steps=[('imputer', SimpleImputer()),
#                                   ('scaling', MinMaxScaler())])),
#                  ('model_svm', SVC())]),
#  'n_jobs': -1,
#  'refit': 'precision',
#  'cv': 5,
#  'verbose': 0,
#  'pre_dispatch': '2*n_jobs',
#  'error_score': nan,
#  'return_train_score': False,
#  'param_grid': {'preprocessing__imputer__strategy': ['mean', 'median'],
#   'model_svm__kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
#   'model_svm__C': [1, 10, 100, 500, 1000]},
#  'multimetric_': False,
#  'best_index_': 3,
#  'best_score_': 0.7553557981990611,
#  'best_params_': {'model_svm__C': 1,
#   'model_svm__kernel': 'poly',
#   'preprocessing__imputer__strategy': 'median'},
#  'best_estimator_': Pipeline(steps=[('preprocessing',
#                   Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),
#                                   ('scaling', MinMaxScaler())])),
#                  ('model_svm', SVC(C=1, kernel='poly'))]),
#  'refit_time_': 0.11969423294067383,
#  'feature_names_in_': array(['games played', 'minutes played', 'points per game',
#         'field goals made', 'field goal attempts', 'field goal percent',
#         '3 point made', '3 point attempt', '3 point %', 'free throw made',
#         'free throw attempts', 'free throw %', 'offensive rebounds',
#         'defensive rebounds', 'rebounds', 'assists', 'steals', 'blocks',
#         'turnovers'], dtype=object),
#  'scorer_': make_scorer(precision_score, average=binary),
#  'cv_results_': {'mean_fit_time': array([ 0.07494535,  0.08333888,  0.12639933,  0.1263207 ,  0.10843391,
#           0.12527924,  0.14832997,  0.14653611,  0.09009919,  0.08490629,
#           0.30996318,  0.29443135,  0.12395544,  0.1222724 ,  0.13575029,
#           0.14810796,  0.21246171,  0.22146034,  2.33826561,  2.08112035,
#           0.27685752,  0.27881794,  0.14201021,  0.14980698,  0.74554782,
#           0.68802004, 10.62843013,  9.4353951 ,  0.78088546,  0.77579737,
#           0.13718348,  0.13807349,  1.16308179,  1.14019537, 20.44220371,
#          18.22205267,  1.35667553,  1.3270884 ,  0.143295  ,  0.13306084]),
#   'std_fit_time': array([4.12558365e-03, 8.97638309e-03, 8.34884154e-03, 8.06786938e-03,
#          2.40599323e-03, 1.56318429e-02, 1.61990123e-02, 1.02989371e-02,
#          5.75179570e-03, 8.72825806e-03, 6.54978515e-02, 2.72376077e-02,
#          8.66499644e-03, 7.14555444e-03, 1.07540596e-02, 5.13454490e-03,
#          2.33264801e-02, 2.43486915e-02, 4.69851508e-01, 3.39858621e-01,
#          2.30900575e-02, 1.22616166e-02, 5.98607115e-03, 7.42144083e-03,
#          2.27373629e-01, 8.54076142e-02, 2.20213587e+00, 2.11960537e+00,
#          6.44976009e-02, 5.25254511e-02, 4.81331520e-03, 7.97444755e-03,
#          2.56254687e-01, 1.09450048e-01, 3.84663634e+00, 3.62665112e+00,
#          1.45913578e-01, 1.71844196e-01, 3.53654894e-03, 1.38899480e-02]),
#   'mean_score_time': array([0.0181695 , 0.01800599, 0.01972032, 0.02037082, 0.06804891,
#          0.05573888, 0.03504925, 0.03402123, 0.0166925 , 0.01607599,
#          0.02066956, 0.01779022, 0.06295948, 0.06023431, 0.03774776,
#          0.03557706, 0.01765938, 0.02107692, 0.02020154, 0.01965151,
#          0.07168455, 0.07077971, 0.03530831, 0.0345181 , 0.01751323,
#          0.01742067, 0.0212348 , 0.01936831, 0.06366067, 0.05720396,
#          0.03558898, 0.03665929, 0.01960721, 0.01932912, 0.02032547,
#          0.01806436, 0.06625991, 0.06103868, 0.03525934, 0.03343506]),
#   'std_score_time': array([0.00110407, 0.00158988, 0.00053815, 0.00093668, 0.00203407,
#          0.01249773, 0.00142447, 0.00151491, 0.00124861, 0.00091391,
#          0.00357295, 0.00083681, 0.00534361, 0.00603915, 0.0078428 ,
#          0.00092152, 0.00072602, 0.0029046 , 0.00217562, 0.00112154,
#          0.00709915, 0.00553789, 0.00092268, 0.00085792, 0.00122996,
#          0.00056846, 0.00340318, 0.0010254 , 0.00168699, 0.01337635,
#          0.00408444, 0.00388671, 0.00473373, 0.00269102, 0.00826126,
#          0.00460851, 0.01122246, 0.00659318, 0.00598449, 0.01006579]),
#   'param_model_svm__C': masked_array(data=[1, 1, 1, 1, 1, 1, 1, 1, 10, 10, 10, 10, 10, 10, 10, 10,
#                      100, 100, 100, 100, 100, 100, 100, 100, 500, 500, 500,
#                      500, 500, 500, 500, 500, 1000, 1000, 1000, 1000, 1000,
#                      1000, 1000, 1000],
#                mask=[False, False, False, False, False, False, False, False,
#                      False, False, False, False, False, False, False, False,
#                      False, False, False, False, False, False, False, False,
#                      False, False, False, False, False, False, False, False,
#                      False, False, False, False, False, False, False, False],
#          fill_value='?',
#               dtype=object),
#   'param_model_svm__kernel': masked_array(data=['linear', 'linear', 'poly', 'poly', 'rbf', 'rbf',
#                      'sigmoid', 'sigmoid', 'linear', 'linear', 'poly',
#                      'poly', 'rbf', 'rbf', 'sigmoid', 'sigmoid', 'linear',
#                      'linear', 'poly', 'poly', 'rbf', 'rbf', 'sigmoid',
#                      'sigmoid', 'linear', 'linear', 'poly', 'poly', 'rbf',
#                      'rbf', 'sigmoid', 'sigmoid', 'linear', 'linear',
#                      'poly', 'poly', 'rbf', 'rbf', 'sigmoid', 'sigmoid'],
#                mask=[False, False, False, False, False, False, False, False,
#                      False, False, False, False, False, False, False, False,
#                      False, False, False, False, False, False, False, False,
#                      False, False, False, False, False, False, False, False,
#                      False, False, False, False, False, False, False, False],
#          fill_value='?',
#               dtype=object),
#   'param_preprocessing__imputer__strategy': masked_array(data=['mean', 'median', 'mean', 'median', 'mean', 'median',
#                      'mean', 'median', 'mean', 'median', 'mean', 'median',
#                      'mean', 'median', 'mean', 'median', 'mean', 'median',
#                      'mean', 'median', 'mean', 'median', 'mean', 'median',
#                      'mean', 'median', 'mean', 'median', 'mean', 'median',
#                      'mean', 'median', 'mean', 'median', 'mean', 'median',
#                      'mean', 'median', 'mean', 'median'],
#                mask=[False, False, False, False, False, False, False, False,
#                      False, False, False, False, False, False, False, False,
#                      False, False, False, False, False, False, False, False,
#                      False, False, False, False, False, False, False, False,
#                      False, False, False, False, False, False, False, False],
#          fill_value='?',
#               dtype=object),
#   'params': [{'model_svm__C': 1,
#     'model_svm__kernel': 'linear',
#     'preprocessing__imputer__strategy': 'mean'},
#    {'model_svm__C': 1,
#     'model_svm__kernel': 'linear',
#     'preprocessing__imputer__strategy': 'median'},
#    {'model_svm__C': 1,
#     'model_svm__kernel': 'poly',
#     'preprocessing__imputer__strategy': 'mean'},
#    {'model_svm__C': 1,
#     'model_svm__kernel': 'poly',
#     'preprocessing__imputer__strategy': 'median'},
#    {'model_svm__C': 1,
#     'model_svm__kernel': 'rbf',
#     'preprocessing__imputer__strategy': 'mean'},
#    {'model_svm__C': 1,
#     'model_svm__kernel': 'rbf',
#     'preprocessing__imputer__strategy': 'median'},
#    {'model_svm__C': 1,
#     'model_svm__kernel': 'sigmoid',
#     'preprocessing__imputer__strategy': 'mean'},
#    {'model_svm__C': 1,
#     'model_svm__kernel': 'sigmoid',
#     'preprocessing__imputer__strategy': 'median'},
#    {'model_svm__C': 10,
#     'model_svm__kernel': 'linear',
#     'preprocessing__imputer__strategy': 'mean'},
#    {'model_svm__C': 10,
#     'model_svm__kernel': 'linear',
#     'preprocessing__imputer__strategy': 'median'},
#    {'model_svm__C': 10,
#     'model_svm__kernel': 'poly',
#     'preprocessing__imputer__strategy': 'mean'},
#    {'model_svm__C': 10,
#     'model_svm__kernel': 'poly',
#     'preprocessing__imputer__strategy': 'median'},
#    {'model_svm__C': 10,
#     'model_svm__kernel': 'rbf',
#     'preprocessing__imputer__strategy': 'mean'},
#    {'model_svm__C': 10,
#     'model_svm__kernel': 'rbf',
#     'preprocessing__imputer__strategy': 'median'},
#    {'model_svm__C': 10,
#     'model_svm__kernel': 'sigmoid',
#     'preprocessing__imputer__strategy': 'mean'},
#    {'model_svm__C': 10,
#     'model_svm__kernel': 'sigmoid',
#     'preprocessing__imputer__strategy': 'median'},
#    {'model_svm__C': 100,
#     'model_svm__kernel': 'linear',
#     'preprocessing__imputer__strategy': 'mean'},
#    {'model_svm__C': 100,
#     'model_svm__kernel': 'linear',
#     'preprocessing__imputer__strategy': 'median'},
#    {'model_svm__C': 100,
#     'model_svm__kernel': 'poly',
#     'preprocessing__imputer__strategy': 'mean'},
#    {'model_svm__C': 100,
#     'model_svm__kernel': 'poly',
#     'preprocessing__imputer__strategy': 'median'},
#    {'model_svm__C': 100,
#     'model_svm__kernel': 'rbf',
#     'preprocessing__imputer__strategy': 'mean'},
#    {'model_svm__C': 100,
#     'model_svm__kernel': 'rbf',
#     'preprocessing__imputer__strategy': 'median'},
#    {'model_svm__C': 100,
#     'model_svm__kernel': 'sigmoid',
#     'preprocessing__imputer__strategy': 'mean'},
#    {'model_svm__C': 100,
#     'model_svm__kernel': 'sigmoid',
#     'preprocessing__imputer__strategy': 'median'},
#    {'model_svm__C': 500,
#     'model_svm__kernel': 'linear',
#     'preprocessing__imputer__strategy': 'mean'},
#    {'model_svm__C': 500,
#     'model_svm__kernel': 'linear',
#     'preprocessing__imputer__strategy': 'median'},
#    {'model_svm__C': 500,
#     'model_svm__kernel': 'poly',
#     'preprocessing__imputer__strategy': 'mean'},
#    {'model_svm__C': 500,
#     'model_svm__kernel': 'poly',
#     'preprocessing__imputer__strategy': 'median'},
#    {'model_svm__C': 500,
#     'model_svm__kernel': 'rbf',
#     'preprocessing__imputer__strategy': 'mean'},
#    {'model_svm__C': 500,
#     'model_svm__kernel': 'rbf',
#     'preprocessing__imputer__strategy': 'median'},
#    {'model_svm__C': 500,
#     'model_svm__kernel': 'sigmoid',
#     'preprocessing__imputer__strategy': 'mean'},
#    {'model_svm__C': 500,
#     'model_svm__kernel': 'sigmoid',
#     'preprocessing__imputer__strategy': 'median'},
#    {'model_svm__C': 1000,
#     'model_svm__kernel': 'linear',
#     'preprocessing__imputer__strategy': 'mean'},
#    {'model_svm__C': 1000,
#     'model_svm__kernel': 'linear',
#     'preprocessing__imputer__strategy': 'median'},
#    {'model_svm__C': 1000,
#     'model_svm__kernel': 'poly',
#     'preprocessing__imputer__strategy': 'mean'},
#    {'model_svm__C': 1000,
#     'model_svm__kernel': 'poly',
#     'preprocessing__imputer__strategy': 'median'},
#    {'model_svm__C': 1000,
#     'model_svm__kernel': 'rbf',
#     'preprocessing__imputer__strategy': 'mean'},
#    {'model_svm__C': 1000,
#     'model_svm__kernel': 'rbf',
#     'preprocessing__imputer__strategy': 'median'},
#    {'model_svm__C': 1000,
#     'model_svm__kernel': 'sigmoid',
#     'preprocessing__imputer__strategy': 'mean'},
#    {'model_svm__C': 1000,
#     'model_svm__kernel': 'sigmoid',
#     'preprocessing__imputer__strategy': 'median'}],
#   'split0_test_score': array([0.7251462 , 0.7251462 , 0.72093023, 0.72093023, 0.74137931,
#          0.73714286, 0.50289017, 0.50289017, 0.72413793, 0.72      ,
#          0.72289157, 0.72727273, 0.73033708, 0.73184358, 0.50289017,
#          0.50289017, 0.72159091, 0.71751412, 0.74172185, 0.74      ,
#          0.72      , 0.7183908 , 0.50581395, 0.50581395, 0.7247191 ,
#          0.71823204, 0.72327044, 0.72258065, 0.68944099, 0.69753086,
#          0.50581395, 0.50581395, 0.72316384, 0.7150838 , 0.70552147,
#          0.7037037 , 0.67901235, 0.67901235, 0.50581395, 0.50581395]),
#   'split1_test_score': array([0.72058824, 0.72058824, 0.7591623 , 0.7591623 , 0.70754717,
#          0.70422535, 0.47169811, 0.47169811, 0.71634615, 0.71770335,
#          0.75555556, 0.75138122, 0.71497585, 0.7184466 , 0.46451613,
#          0.46451613, 0.71980676, 0.71770335, 0.73964497, 0.73684211,
#          0.73513514, 0.73262032, 0.46451613, 0.46451613, 0.71980676,
#          0.71634615, 0.73913043, 0.73939394, 0.72727273, 0.7202381 ,
#          0.46451613, 0.46451613, 0.72330097, 0.71634615, 0.73417722,
#          0.75159236, 0.72049689, 0.70886076, 0.46451613, 0.46451613]),
#   'split2_test_score': array([0.79166667, 0.79166667, 0.77941176, 0.7810219 , 0.7804878 ,
#          0.78181818, 0.50568182, 0.50568182, 0.78181818, 0.78181818,
#          0.75373134, 0.7480916 , 0.74125874, 0.73793103, 0.50857143,
#          0.50857143, 0.78658537, 0.79141104, 0.7421875 , 0.72727273,
#          0.72142857, 0.71014493, 0.50857143, 0.50857143, 0.7826087 ,
#          0.78395062, 0.69767442, 0.68656716, 0.69402985, 0.69117647,
#          0.50857143, 0.50857143, 0.7826087 , 0.7826087 , 0.67692308,
#          0.66935484, 0.68421053, 0.68613139, 0.50857143, 0.50857143]),
#   'split3_test_score': array([0.72316384, 0.7247191 , 0.74842767, 0.75316456, 0.72777778,
#          0.73184358, 0.49704142, 0.49704142, 0.73142857, 0.73142857,
#          0.71710526, 0.71895425, 0.73684211, 0.74269006, 0.48484848,
#          0.48484848, 0.72067039, 0.72928177, 0.70833333, 0.71621622,
#          0.7030303 , 0.71257485, 0.48484848, 0.48484848, 0.71823204,
#          0.7247191 , 0.67361111, 0.68055556, 0.67973856, 0.67785235,
#          0.48484848, 0.48484848, 0.71666667, 0.72316384, 0.69178082,
#          0.68965517, 0.67320261, 0.67105263, 0.48484848, 0.48484848]),
#   'split4_test_score': array([0.72777778, 0.72777778, 0.7625    , 0.7625    , 0.72131148,
#          0.71978022, 0.50898204, 0.50898204, 0.73295455, 0.73295455,
#          0.73125   , 0.73291925, 0.73184358, 0.73743017, 0.5       ,
#          0.5       , 0.71428571, 0.71823204, 0.74522293, 0.75316456,
#          0.73170732, 0.72727273, 0.5       , 0.5       , 0.71584699,
#          0.71978022, 0.74025974, 0.73856209, 0.69620253, 0.7037037 ,
#          0.5       , 0.5       , 0.71584699, 0.71823204, 0.7388535 ,
#          0.73717949, 0.7030303 , 0.7005988 , 0.5       , 0.5       ]),
#   'mean_test_score': array([0.73766854, 0.7379796 , 0.75408639, 0.7553558 , 0.73570071,
#          0.73496204, 0.49725871, 0.49725871, 0.73733708, 0.73678093,
#          0.73610675, 0.73572381, 0.73105147, 0.73366829, 0.49216524,
#          0.49216524, 0.73258783, 0.73482847, 0.73542212, 0.73469912,
#          0.72226027, 0.72020073, 0.49275   , 0.49275   , 0.73224272,
#          0.73260563, 0.71478923, 0.71353188, 0.69733693, 0.6981003 ,
#          0.49275   , 0.49275   , 0.73231743, 0.73108691, 0.70945122,
#          0.71029711, 0.69199054, 0.68913119, 0.49275   , 0.49275   ]),
#   'std_test_score': array([0.02710187, 0.02694207, 0.01933536, 0.01956629, 0.02490211,
#          0.02602003, 0.0133678 , 0.0133678 , 0.02301096, 0.02331179,
#          0.0157998 , 0.01231764, 0.00891385, 0.00835158, 0.01589704,
#          0.01589704, 0.02711831, 0.02863861, 0.01366124, 0.01241316,
#          0.01123033, 0.00856514, 0.0163287 , 0.0163287 , 0.02534998,
#          0.02582234, 0.02569718, 0.02526567, 0.01600265, 0.01399802,
#          0.0163287 , 0.0163287 , 0.02533976, 0.02590717, 0.02392336,
#          0.03024497, 0.01741515, 0.01384909, 0.0163287 , 0.0163287 ]),
#   'rank_test_score': array([ 4,  3,  2,  1,  9, 11, 31, 31,  5,  6,  7,  8, 20, 14, 39, 39, 16,
#          12, 10, 13, 21, 22, 33, 33, 18, 15, 23, 24, 28, 27, 33, 33, 17, 19,
#          26, 25, 29, 30, 33, 33], dtype=int32)},
#  'n_splits_': 5}

# %%
search.best_estimator_
# Out:
# Pipeline(steps=[('preprocessing',
#                  Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),
#                                  ('scaling', MinMaxScaler())])),
#                 ('model_svm', SVC(C=1, kernel='poly'))])

# %%
from nbresult import ChallengeResult

result = ChallengeResult('solution',
    search = search
)
result.write()
print(result.check())
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.12, pytest-6.2.5, py-1.11.0, pluggy-1.0.0 -- /home/cherif/.pyenv/versions/lewagon/bin/python3
# cachedir: .pytest_cache
# rootdir: /home/cherif/code/cherifbenham/data-challenges/05-ML/08-Workflow/03-Tuning-Pipeline
# plugins: anyio-3.4.0
# collecting ... collected 1 item
#
# tests/test_solution.py::TestSolution::test_cv_results PASSED             [100%]
#
# ============================== 1 passed in 0.59s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/solution.pickle
#
# git commit -m 'Completed solution step'
#
# git push origin master

# %% [markdown]
# ## Export

# %% [markdown]
# Once you have built your optimal pipeline, export it as a pickle file

# %%
import pickle

# Export pipeline as pickle file
with open("pipeline.pkl", "wb") as file:
    pickle.dump(pipe, file )

# %% [markdown]
# 🏁 Congratulation. Don't forget to add, commit and push your notebook.
